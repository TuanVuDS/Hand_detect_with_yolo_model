# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !git reset --hard fbe67e465375231474a2ad80a4389efc77ecff99
# Out:
# /content/gdrive/MyDrive
# /content/gdrive/MyDrive/yolov5

# %%
# !pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 1.6 MB 34.3 MB/s

# %%
# import torch

# from IPython.display import Image, clear_output 
# from utils.downloads import attempt_download  # to download models/datasets

# # clear_output()
# print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !rm data/mydataset.yaml # nếu có
# !echo 'train: /content/gdrive/MyDrive/Computer Vision/train_data_hand/train' >> data/mydataset.yaml
# !echo 'val: /content/gdrive/MyDrive/Computer Vision/train_data_hand/valid' >> data/mydataset.yaml
# !echo 'nc: 4' >> data/mydataset.yaml

# !echo "names: ['myleft', 'myright', 'yourleft', 'yourright']" >> data/mydataset.yaml

# %% [markdown]
# ###version yolov5s

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 100 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5s.yaml --weights '' --name yolov5s_results  --cache

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 2 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5s.yaml --weights '/content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt' --name yolov5ss_results  --cache
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=/content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt, cfg=/content/gdrive/MyDrive/yolov5/models/yolov5s.yaml, data=/content/gdrive/MyDrive/yolov5/data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5ss_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# ...

# %%
# !python detect.py --weight /content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt --source /content/gdrive/MyDrive/yolov5/data/images/CARDS_COURTYARD_B_T_frame_0036_jpg.rf.7cfade7984bfb63cfbc28b61526221dd.jpg

# %%
# !python detect.py --weight /content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt --source /content/gdrive/MyDrive/yolov5/data/images/cards_courtyard_H_S.mp4

# %% [markdown]
# ###version yolov5x

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 100 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5x.yaml --weights '' --name yolov5x_results  --cache
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=, cfg=/content/gdrive/MyDrive/yolov5/models/yolov5x.yaml, data=/content/gdrive/MyDrive/yolov5/data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5x_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-306-gfbe67e4 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ###version yolo5n

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 60 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5n.yaml --weights '' --name yolov5n_results  --cache
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=, cfg=/content/gdrive/MyDrive/yolov5/models/yolov5n.yaml, data=/content/gdrive/MyDrive/yolov5/data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5n_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# requirements: ipython not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# ...

# %% [markdown]
# ###version yolo5m

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 70 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5m.yaml --weights '' --name yolov5m_results  --cache
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=, cfg=/content/gdrive/MyDrive/yolov5/models/yolov5m.yaml, data=/content/gdrive/MyDrive/yolov5/data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=70, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5m_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.
# ...

# %% [markdown]
# ###version yolo5l

# %%
# %cd /content/gdrive/MyDrive/yolov5
# !python train.py --img 416 --batch 16 --epochs 65 --data /content/gdrive/MyDrive/yolov5/data/mydataset.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5l.yaml --weights '' --name yolov5l_results  --cache
# Out:
# /content/gdrive/MyDrive/yolov5
# train: weights=, cfg=/content/gdrive/MyDrive/yolov5/models/yolov5l.yaml, data=/content/gdrive/MyDrive/yolov5/data/mydataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=65, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5l_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 228 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-306-gfbe67e4 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ###test

# %%
# !python detect.py --weight /content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt --source /content/gdrive/MyDrive/yolov5/data/images/cards_courtyard_H_S.mp4 --view-img --conf-thres 0.9
# Out:
# detect: weights=['/content/gdrive/MyDrive/yolov5/runs/train/yolov5s_results/weights/best.pt'], source=/content/gdrive/MyDrive/yolov5/data/images/cards_courtyard_H_S.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=, view_img=True, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-306-gfbe67e4 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/usr/local/lib/python3.7/dist-packages/cv2/qt/plugins" even though it was found.
# ...
